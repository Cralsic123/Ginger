# %% [markdown]
# <a href="https://colab.research.google.com/github/Cralsic123/Ginger/blob/main/Untitled36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('BETTER30.csv')

# %%
df.sample(5)
# Out:
#      CONVERSATION_ID  CONVERSATION_STEP  \
# 448               53                  8
# 266               36                  9
# 326               43                  4
# 43                 4                  8
# 431               52                  6
#
#                                                   TEXT  \
# 448  This could delay the compliance process and po...
# 266  You're welcome! We look forward to helping you...
# 326  It was filed three days ago. For security reas...
# 43   Fine, I'll try to find someone else... [Goal S...
# 431  Certainly, my badge number is 019283. However,...
#
#                                                CONTEXT                LABEL  \
# 448   "Scammer warns of negative consequences for n...                 scam
# 266                          Ends call with positivity           legitimate
# 326  Provides vague details and asks for sensitive ...                 scam
# 43                Open to helping, emphasizes security  slightly_suspicious
# ...

# %%
df.drop(columns = ["CONVERSATION_ID",	"CONVERSATION_STEP"])
# Out:
#                                                   TEXT  \
# 0    Good morning, this is [Your Name]'s personal a...
# 1    Hello, my name is Jamie. I'm interested in vol...
# 2    Yes, I'm really passionate about environmental...
# 3    Great, how do I sign up, and where can I find ...
# 4    Could you send me the link, please? And my ema...
# ..                                                 ...
# 645  Would it be possible to receive some literatur...
# 646  We can certainly provide information on our wo...
# 647  I understand the urgency, but our policy is to...
# 648  I'll do my best to get you the information qui...
# 649  Thank you. We look forward to reviewing the in...
#
#                                                CONTEXT           LABEL  \
# 0                            Standard opening exchange         neutral
# 1                     Encourages the caller's interest         neutral
# 2                      Reinforces anyone can volunteer         neutral
# ...
